# %%
import os
import pandas as pd
import numpy as np
print(os.getcwd())
# Out:
# C:\Users\em18921\Documents\Sentinels_indicator\Codes_folder

# %%
file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Search_terms_raw_file\geopoltiks_test.txt'

with open(file_path, 'r') as file:
    contents = file.read()
    print(contents)

# %%
# Step 2: Split the string by delimiter
data_list = contents.splitlines()

# Step 3: Add double quotes around each element and remove leading/trailing spaces, then join with commas
formatted_data = ', '.join([f'"{item.strip()}"' for item in data_list])

# Output the result
print(formatted_data)
# Out:
# "act of terrorism", "act of war", "army", "assassination", "atomic bomb", "cold war", "combat", "conflict", "coup", "diplomacy", "embargo", "fascism", "hostage crisis", "hydrogen bomb", "idf", "justice", "manhattan project", "massacre", "military base", "military combat", "militia", "nuclear power plants", "nuclear test", "nuclear war", "peace treaty", "pentagon", "protest", "red scare", "start of war", "tariff", "tariffs", "terrorism", "terrorist", "threats", "total war", "treaty", "trench warfare", "troop", "war", "war news", "war weapons", "warfare", "warriors", "weapons of mass destruction", "world order", "world war", "nuclear weapon", "peace symbols", "trade war", "war weapon", "warhead", "hypersonic missile", "embargo act", "terrorist act", "insurgents", "missile launch", "submarine warfare", "humanitarian aid", "war effort", "war powers act", "conscription", "insurrection", "lebanon war", "triple alliance", "warheads", "oil crisis", "iran us tensions", "cruise missile", "troo
# ...

# %%
# Merge datasets

path_1 = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\geopoltiks_all_merged_set.csv'

path_2 = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_new_input_filesl_data\geopoltiks_merged_set.csv'

df_1 = pd.read_csv(path_1)

df_2 = pd.read_csv(path_2)

#df_2.rename(columns = {'batch_number' : 'wf_comp_batch_no'}, inplace=True)

df_merge = pd.concat([df_1, df_2], ignore_index=True)

df_merge

# Keep keyword_name
keep_keyword_name = [ "act of terrorism", "act of war", "army", "assassination", "atomic bomb", "cold war", "combat", "conflict", "coup", "diplomacy", "embargo", "fascism", "hostage crisis", "hydrogen bomb", "idf", "justice", "manhattan project", "massacre", "military base", "military combat", "militia", "nuclear power plants", "nuclear test", "nuclear war", "peace treaty", "pentagon", "protest", "red scare", "start of war", "tariff", "tariffs", "terrorism", "terrorist", "threats", "total war", "treaty", "trench warfare", "troop", "war", "war news", "war weapons", "warfare", "warriors", "weapons of mass destruction", "world order", "world war", "nuclear weapon", "peace symbols", "trade war", "war weapon", "warhead", "hypersonic missile", "embargo act", "terrorist act", "insurgents", "missile launch", "submarine warfare", "humanitarian aid", "war effort", "war powers act", "conscription", "insurrection", "lebanon war", "triple alliance", "warheads", "oil crisis", "iran us tensions", "cruise missile", "troops", "truce agreement", "arms treaty", "refugee crisis", "domestic terrorism", "economic sanctions", "arms race", "military arms", "military coup", "war hostage", "trade sanctions", "war neutrality", "nuclear missiles", "geopolitical conflict", "war is imminent", "russian troops", "geopolitics", "air battles", "military clashes", "trade embargo", "military branch", "ceasefire", "paris attacks", "air force", "alliance", "allied powers", "american revolution", "terrorist attacks", "terrorist attack", "political risk", "military press", "military operation", "central intelligence agency", "invade", "peace corps", "refugees", "post war", "policy", "bombs", "world peace", "patriot act", "military news", "bombings", "cia", "armed forces", "the great war", "military", "foreign  policy", "peace process", "attack on military base", "trade tariff", "military strategy", "oil embargo", "war scare", "nuclear missile", "christmas truce", "navy", "bomb", "naval warfare", "air warfare", "geopolitical", "naval blockades", "geopolitical news", "armistice", "peace", "nuclear bomb", "genocide", "human migration", "nationalism", "nato", "invasion", "religious text", "international terrorism", "terrorist killed", "missile test", "the great fear", "outbreak of world war", "allies of world war", "peace talks", "on the brink of world war 3", "peace tea", "god", "military strike", "outbreak of war", "russian invasion", "iran attack israel", "nazism", "war efforts", "war rebels", "peace talk", "military drones", "neutral countries", "plane hijack", "war refugee", "global peace index", "an act of war", "war blockade", "drone strikes", "brink of war", "central powers", "military dictatorship", "war imminent", "breach of the peace", "nato troops", "nukemap", "geopolitical community", "small arms treaty", "military drone", "nuclear threats", "drone warfare", "drone strike", "offensive military", "military motivation", "militarism", "soldiers surrender", "missile crisis", "war hostages", "geopolitical risks", "the insurgents", "tariff news", "military drills", "us china tensions", "military buildup", "neutral country", "escalation of war", "surgical strike", "gulf of tonkin", "military alliance", "guerrilla warfare", "anti-war movement", "geopolitical events", "what are sanctions in war", "military advance", "geopolitical strategy", "russo-ukrainian war", "us and china tensions", "war blockades", "military build-up", "geopolitical boundaries", "military and foreign affairs", "brink of world war", "troops at the border"]


df_merge = df_merge[df_merge['keyword_name'].isin(keep_keyword_name)]

df_merge = df_merge.drop_duplicates(subset=['keyword_name', 'Year', 'Month', 'Day'], keep="first")

df_unique = df_merge[['keyword_name', 'Year']].drop_duplicates()

df_unique['Year_number'] = df_unique['Year'] - 2003

# Define the year range, i.e 2003 to 2025
all_years = range(2003, 2025)

# Get all unique keyword_name data
df_unique_key = df_merge['keyword_name'].unique()

# Create a cross dataset with unique keyword_name and all_years
cross_data = pd.DataFrame([(keyword_name, Year) for keyword_name in df_unique_key for Year in all_years],
                         columns = ['keyword_name', 'Year'])

# Merge the cross data with df_unique and keep the indicator on
df_merge_2 = pd.merge(df_unique, cross_data, on=['keyword_name', 'Year'], how='right', indicator=True)

# Output dataset
output_file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\geopoltiks_test_dataset.csv'
df_merge.to_csv(output_file_path, index=False)


# Output dataset
output_file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\csvmeta_data_4.csv'
df_merge_2.to_csv(output_file_path, index=False)

df_merge
# Out:
# C:\Users\em18921\AppData\Local\Temp\ipykernel_3496\2499766962.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv(path_1)
#               date  Year  Month  Day  batch_number        keyword_name SVI
# 0       2003-12-28  2003     12   28     apidata_1      missile launch   0
# 1       2004-01-04  2004      1    4     apidata_1      missile launch   0
# 2       2004-01-11  2004      1   11     apidata_1      missile launch   0
# 3       2004-01-18  2004      1   18     apidata_1      missile launch   0
# 4       2004-01-25  2004      1   25     apidata_1      missile launch   0
# ...            ...   ...    ...  ...           ...                 ...  ..
# 480939  2024-11-10  2024     11   10  apidata_1016  geopolitical risks   0
# 480940  2024-11-17  2024     11   17  apidata_1016  geopolitical risks   0
# 480941  2024-11-24  2024     11   24  apidata_1016  geopolitical risks  31
# ...

# %%
path_3 = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\keyword_name_type.csv'
df_3 = pd.read_csv(path_3)

path_1 = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\geopoltiks_test_dataset.csv'
df_1 = pd.read_csv(path_1)

df_merge = pd.merge(df_1, df_3, on=['keyword_name'], how='left')
df_merge

path_1 = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\original_week_date_ver2.csv'
df_2 = pd.read_csv(path_1)

df_merge_2 = pd.merge(df_merge, df_2, on=['date'], how='left')
df_merge_2

output_file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\geopoltiks_test_dataset_2.csv'
df_merge_2.to_csv(output_file_path, index=False)

print(f"Length of original dataset {df_1.shape[0]}")
print(f"Length of dataset after merge 1 {df_merge.shape[0]}")
print(f"Length of dataset after merge 2 {df_merge_2.shape[0]}")
# Out:
# C:\Users\em18921\AppData\Local\Temp\ipykernel_3496\4130028220.py:5: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv(path_1)
# Length of original dataset 178563
# Length of dataset after merge 1 179554
# Length of dataset after merge 2 179554

# %%
import pandas as pd
# calculating monthly change in gpr

path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_new_input_filesl_data\GPR_downloaded_data.csv'
df = pd.read_csv(path)

df['gpr_monthly_change'] = df['GPR_paper'].diff()
df['gpr_Volatility'] = df['gpr_monthly_change'].rolling(window=1).std()

df

output_file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\GPR_datastep.csv'
df.to_csv(output_file_path, index=False)
df

# %%
pip install yfinance

# %%
import yfinance as yf

# Define the VIX ticker symbol
vix_ticker = "^VIX"

# Download VIX data with weekly frequency
vix_data_weekly = yf.download(
    vix_ticker,
    start="2003-12-31",
    end="2024-12-31",
    interval="1wk"  # Weekly frequency
)

# Save the data to a CSV file (optional)
#vix_data_weekly.to_csv("vix_data_weekly.csv")
#print("Weekly VIX data saved to 'vix_data_weekly.csv'")

output_file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_new_input_filesl_data\VIX_input_file.csv'
vix_data_weekly.to_csv(output_file_path, index=False)
vix_data_weekly

# %%
path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_new_input_filesl_data\snp500_data.csv'
df = pd.read_csv(path)

# Calculate rolling standard deviation (volatility) over a 14-day period
df['snp_Volatility'] = df['weekly_index_return_deci'].rolling(window=4).std()

output_file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\snp500_data_vol.csv'
df.to_csv(output_file_path, index=False)
df

# %%
path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_new_input_filesl_data\snp500_data.csv'
df = pd.read_csv(path)

# Calculate rolling standard deviation (volatility) over a 14-day period
df['snp_Volatility'] = df['weekly_index_return_deci'].rolling(window=4).std()

output_file_path = r'C:\Users\em18921\Documents\Sentinels_indicator\Geopolitiks_output_folder_16Dec\snp500_data_vol.csv'
df.to_csv(output_file_path, index=False)
df
# Out:
#             date  snp500_tot_return  weekly_index_return_deci  \
# 0      1/10/2003            1479.23                       NaN
# 1      8/10/2003            1502.65                  0.015833
# 2     15/10/2003            1521.95                  0.012844
# 3     22/10/2003            1498.28                 -0.015552
# 4     29/10/2003            1524.41                  0.017440
# ...          ...                ...                       ...
# 1095  27/09/2024           12553.78                  0.006360
# 1096   4/10/2024           12586.91                  0.002639
# 1097  11/10/2024           12729.52                  0.011330
# 1098  18/10/2024           12840.30                  0.008703
# 1099  25/10/2024           12717.34                 -0.009576
#
#       weekly_index_return_prcnt index_name  time_series_period_week  \
# 0                           NaN    snp_500                      NaN
# 1                           NaN    snp_500                      NaN
# ...
